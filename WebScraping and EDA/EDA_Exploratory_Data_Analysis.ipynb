# %% [markdown]
# <a href="https://colab.research.google.com/github/meenamahanth/DataScience/blob/main/WebScraping%20and%20EDA/EDA_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # used for lineplot,boxplot

# %% [markdown]
# Add the cars.csv in the files tab you can get it from the below link

# %%
df = pd.read_csv('cars.csv')  # https://github.com/meenamahanth/DataScience/blob/main/WebScraping%20and%20EDA/cars.csv # CTRL + Click to open the URL

# %% [markdown]
# To get the first 5 rows

# %%
df.head()
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm  ... Leather_Wrapped_Steering Automatic_Headlamps Engine_Type  \
# ...

# %% [markdown]
# To get the last 5 rows

# %%
df.tail()
# Out:
#             Make    Model        Variant Ex-Showroom_Price Displacement  \
# 1271       Honda     City   Vx Mt Diesel     Rs. 13,02,000      1498 cc
# 1272       Honda     City   Zx Mt Diesel     Rs. 14,21,000      1498 cc
# 1273       Honda     City  Zx Cvt Petrol     Rs. 14,31,000      1497 cc
# 1274       Honda     City   V Cvt Petrol     Rs. 12,01,000      1497 cc
# 1275  Mitsubishi  Montero         3.2 At     Rs. 68,62,560      3200 cc
#
#       Cylinders  Valves_Per_Cylinder               Drivetrain  \
# 1271        4.0                  4.0  FWD (Front Wheel Drive)
# 1272        4.0                  4.0  FWD (Front Wheel Drive)
# 1273        4.0                  4.0  FWD (Front Wheel Drive)
# 1274        4.0                  4.0  FWD (Front Wheel Drive)
# 1275        4.0                  4.0    AWD (All Wheel Drive)
#
#      Cylinder_Configuration Emission_Norm  ... Leather_Wrapped_Steering  \
# 1271                In-line         BS IV  ...                      Yes
# ...

# %% [markdown]
# To get the length of the dataframe (rows)

# %%
len(df)
# Out:
# 1276

# %% [markdown]
# To get the no of rows and columns

# %%
df.shape
# Out:
# (1276, 140)

# %% [markdown]
# To get the numerical columns

# %%
df.describe()
# Out:
#          Cylinders  Valves_Per_Cylinder        Doors  Seating_Capacity  \
# count  1210.000000          1174.000000  1272.000000       1270.000000
# mean      4.380992             3.977853     4.550314          5.270079
# std       1.660957             0.833763     0.747816          1.145231
# min       2.000000             1.000000     2.000000          2.000000
# 25%       4.000000             4.000000     4.000000          5.000000
# 50%       4.000000             4.000000     5.000000          5.000000
# 75%       4.000000             4.000000     5.000000          5.000000
# max      16.000000            16.000000     5.000000         16.000000
#
#        Number_of_Airbags  USB_Ports
# count        1141.000000  29.000000
# mean            3.787029   1.793103
# std             2.522399   0.773642
# min             1.000000   1.000000
# 25%             2.000000   1.000000
# 50%             2.000000   2.000000
# 75%             6.000000   2.000000
# ...

# %% [markdown]
# To check the null values for each columns

# %%
df.isnull().sum()
# Out:
# Make                   75
# Model                   0
# Variant                 0
# Ex-Showroom_Price       0
# Displacement           12
#                      ...
# USB_Ports            1247
# Heads-Up_Display     1225
# Welcome_Lights       1207
# Battery              1263
# Electric_Range       1259
# Length: 140, dtype: int64

# %% [markdown]
# To get the no of datatypes in columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 140 entries, Make to Electric_Range
# dtypes: float64(6), object(134)
# memory usage: 1.4+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# To get the unique values

# %%
df['Make'].unique()
# Out:
# array(['Tata', 'Datsun', 'Renault', 'Maruti Suzuki', 'Hyundai', 'Premier',
#        'Toyota', 'Nissan', 'Volkswagen', 'Ford', 'Mahindra', 'Fiat',
#        'Honda', 'Jeep', 'Isuzu', 'Skoda', 'Audi', nan, 'Dc', 'Mini',
#        'Volvo', 'Jaguar', 'Bmw', 'Land Rover', 'Porsche', 'Lexus',
#        'Maserati', 'Lamborghini', 'Bentley', 'Ferrari', 'Aston Martin',
#        'Bugatti', 'Bajaj', 'Icml', 'Force', 'Mg', 'Kia',
#        'Land Rover Rover', 'Mitsubishi', 'Maruti Suzuki R'], dtype=object)

# %%
df['Cylinders'].unique()
# Out:
# array([ 2.,  3.,  4., nan,  5.,  6.,  8., 12., 10., 16.])

# %% [markdown]
# Plotting

# %%
# Countplot
plt.figure(figsize=(10,5))
sns.countplot(x='Cylinders',hue='Cylinders',data=df)  # hue gives the legend i.e the top right box
# Out:
# <Axes: xlabel='Cylinders', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='Make',hue='Make',data=df)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Cylinder_Configuration',hue='Cylinder_Configuration',data=df)
# Out:
# <Axes: xlabel='Cylinder_Configuration', ylabel='count'>

# %%
# Plot for the Make and hue for Cylinder_Configuration
plt.figure(figsize=(25,10))
sns.countplot(x='Make',hue='Cylinder_Configuration',data=df)
# Out:
# <Axes: xlabel='Make', ylabel='count'>

# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading the DataSet

# %%
df = pd.read_csv('data.csv')  # https://github.com/meenamahanth/DataScience/blob/main/WebScraping%20and%20EDA/data.csv

# %% [markdown]
# To get the top 5 rows to get two rows write head(2)

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# To get the last 5 rows

# %%
df.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %% [markdown]
# No of rows

# %%
len(df)
# Out:
# 11914

# %% [markdown]
# To get no of rows and no of columns

# %%
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# Gives Statistical info of all numerical columns

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %% [markdown]
# Gives the description of the every columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# To get the sum of all the null values

# %%
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# To get the percentage of the null values

# %%
df.isnull().sum()/len(df)*100
# Out:
# Make                  0.000000
# Model                 0.000000
# Year                  0.000000
# Engine Fuel Type      0.025180
# Engine HP             0.579151
# Engine Cylinders      0.251805
# Transmission Type     0.000000
# Driven_Wheels         0.000000
# Number of Doors       0.050361
# Market Category      31.408427
# Vehicle Size          0.000000
# Vehicle Style         0.000000
# highway MPG           0.000000
# city mpg              0.000000
# Popularity            0.000000
# MSRP                  0.000000
# dtype: float64

# %% [markdown]
# To get the unique values of the market category column why market category because it has highest no of null values

# %%
df['Market Category'].unique()
# Out:
# array(['Factory Tuner,Luxury,High-Performance', 'Luxury,Performance',
#        'Luxury,High-Performance', 'Luxury', 'Performance', 'Flex Fuel',
#        'Flex Fuel,Performance', nan, 'Hatchback',
#        'Hatchback,Luxury,Performance', 'Hatchback,Luxury',
#        'Luxury,High-Performance,Hybrid', 'Diesel,Luxury',
#        'Hatchback,Performance', 'Hatchback,Factory Tuner,Performance',
#        'High-Performance', 'Factory Tuner,High-Performance',
#        'Exotic,High-Performance', 'Exotic,Factory Tuner,High-Performance',
#        'Factory Tuner,Performance', 'Crossover', 'Exotic,Luxury',
#        'Exotic,Luxury,High-Performance', 'Exotic,Luxury,Performance',
#        'Factory Tuner,Luxury,Performance', 'Flex Fuel,Luxury',
#        'Crossover,Luxury', 'Hatchback,Factory Tuner,Luxury,Performance',
#        'Crossover,Hatchback', 'Hybrid', 'Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance',
# ...

# %% [markdown]
# This gives the count of the values excluding the null values

# %%
df['Market Category'].value_counts()
# Out:
# Market Category
# Crossover                                          1110
# Flex Fuel                                           872
# Luxury                                              855
# Luxury,Performance                                  673
# Hatchback                                           641
#                                                    ...
# Crossover,Exotic,Luxury,High-Performance              1
# Crossover,Exotic,Luxury,Performance                   1
# Performance,Hybrid                                    1
# Exotic,Luxury,High-Performance,Hybrid                 1
# Flex Fuel,Factory Tuner,Luxury,High-Performance       1
# Name: count, Length: 71, dtype: int64

# %% [markdown]
# Replacing the null values in the market category column with the highest frequency i.e CrossOver in the above table

# %%
df['Market Category'].fillna('Crossover',inplace=True)
# Out:
# <ipython-input-29-8c1c141af73a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Market Category'].fillna('Crossover',inplace=True)

# %%
df['Market Category'].value_counts()
# Out:
# Market Category
# Crossover                                          4852
# Flex Fuel                                           872
# Luxury                                              855
# Luxury,Performance                                  673
# Hatchback                                           641
#                                                    ...
# Crossover,Exotic,Luxury,High-Performance              1
# Crossover,Exotic,Luxury,Performance                   1
# Performance,Hybrid                                    1
# Exotic,Luxury,High-Performance,Hybrid                 1
# Flex Fuel,Factory Tuner,Luxury,High-Performance       1
# Name: count, Length: 71, dtype: int64

# %%
df['Market Category'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP            69
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Market Category       0
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %% [markdown]
# Instead of dropping null values

# %%
df['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
df['Engine HP'].value_counts()
# Out:
# Engine HP
# 200.0    456
# 170.0    351
# 210.0    320
# 240.0    268
# 285.0    246
#         ...
# 592.0      1
# 573.0      1
# 670.0      1
# 557.0      1
# 97.0       1
# Name: count, Length: 356, dtype: int64

# %% [markdown]
# Replacing the Engine H.P with the most frequent values i.e 200 H.P

# %%
df['Engine HP'].fillna(200,inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine Fuel Type      3
# Engine HP             0
# Engine Cylinders     30
# Transmission Type     0
# Driven_Wheels         0
# Number of Doors       6
# Market Category       0
# Vehicle Size          0
# Vehicle Style         0
# highway MPG           0
# city mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
# Drop the null values in the dataframes as they are having the lower significant values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %% [markdown]
# After removing the null values the df shape is reduced the data is cleansed

# %%
df.shape
# Out:
# (11875, 16)

# %%
df1 = df.drop(['Engine Fuel Type',
             'Market Category',
              'Vehicle Style',
               'Popularity',
               'Number of Doors',
               'Vehicle Size'],axis=1)

# %%
df1.head()
# Out:
#   Make       Model  Year  Engine HP  Engine Cylinders Transmission Type  \
# 0  BMW  1 Series M  2011      335.0               6.0            MANUAL
# 1  BMW    1 Series  2011      300.0               6.0            MANUAL
# 2  BMW    1 Series  2011      300.0               6.0            MANUAL
# 3  BMW    1 Series  2011      230.0               6.0            MANUAL
# 4  BMW    1 Series  2011      230.0               6.0            MANUAL
#
#       Driven_Wheels  highway MPG  city mpg   MSRP
# 0  rear wheel drive           26        19  46135
# 1  rear wheel drive           28        19  40650
# 2  rear wheel drive           28        20  36350
# 3  rear wheel drive           28        18  29450
# 4  rear wheel drive           28        18  34500

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
# Renaming the columns names in df1
df1 =df1.rename(columns={'Make':'Brand',
                'Engine HP':'HP',
                'Engine Cylinders':'Cylinder',
                         'Transmission Type':'Transmission'})

# %%
df1.head()
# Out:
#   Brand       Model  Year     HP  Cylinder Transmission     Driven_Wheels  \
# 0   BMW  1 Series M  2011  335.0       6.0       MANUAL  rear wheel drive
# 1   BMW    1 Series  2011  300.0       6.0       MANUAL  rear wheel drive
# 2   BMW    1 Series  2011  300.0       6.0       MANUAL  rear wheel drive
# 3   BMW    1 Series  2011  230.0       6.0       MANUAL  rear wheel drive
# 4   BMW    1 Series  2011  230.0       6.0       MANUAL  rear wheel drive
#
#    highway MPG  city mpg   MSRP
# 0           26        19  46135
# 1           28        19  40650
# 2           28        20  36350
# 3           28        18  29450
# 4           28        18  34500

# %%
# Dropping duplicate rows in the df1 data
df1= df1.drop_duplicates()

# %%
df1.shape
# Out:
# (10886, 10)

# %%
# Use plt to create the figure and sns.lineplot for the line plot
plt.figure(figsize=(10,10))
sns.lineplot(data=df1,x='Year',y='HP')
# Out:
# <Axes: xlabel='Year', ylabel='HP'>

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=df1,x='Year',y='HP')
# Out:
# <Axes: xlabel='Year', ylabel='HP'>

# %% [markdown]
# To detect the outliers in df we have MSRP

# %%
sns.boxplot(df1['MSRP'])
# Out:
# <Axes: ylabel='MSRP'>

# %%
sns.boxplot(df1['HP'])  # the blue box represent the most number of models in the the range s
# Out:
# <Axes: ylabel='HP'>

# %%
sns.boxplot(df1['Cylinder'])
# Out:
# <Axes: ylabel='Cylinder'>

# %%
df1.Brand.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Brand'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df1,x='Year',y='HP')
# Out:
# <Axes: xlabel='Year', ylabel='HP'>

# %%
df1.Transmission.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Transmission'>

# %%
df2 = df1[['Year','HP','Cylinder','highway MPG','city mpg','MSRP']]

# %%
# plotting the heat map
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# plotting the heat map in different colors

# %%
# plotting the heat map in different colors
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='viridis')
plt.show()

# %%
# plotting the heat map
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='plasma')
plt.show()

# %%
# plotting the heat map
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='inferno')
plt.show()

# %%
# plotting the heat map
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='magma')
plt.show()

# %%
# plotting the heat map in different colors
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='bwr')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='hot')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='cool')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='coolwarm_r')  # reverse of the coolwarm
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='Reds')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='Greens')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df2.corr(),annot=True,cmap='Greens_r') # reverse order sense it from the left bar
plt.show()

# %%
# Scatterplot for Year and MSRP
plt.figure(figsize=(10,5))
sns.scatterplot(x='Year',y='MSRP',data=df1)
plt.show()

# %%
# scatter plot between year and HP
plt.figure(figsize=(10,10))
sns.scatterplot(data=df1,x='Year',y='HP')
# Out:
# <Axes: xlabel='Year', ylabel='HP'>

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(df1['HP'],df1['MSRP'])
ax.set_xlabel('HP')
ax.set_ylabel('MSRP')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='HP',y='MSRP',data=df1)
# Out:
# <Axes: xlabel='HP', ylabel='MSRP'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='HP', y='MSRP',data=df1)
# Out:
# <Axes: xlabel='HP', ylabel='MSRP'>

# %%
# ploting the bargraph
plt.figure(figsize=(30,5))
sns.barplot(x='Brand',y='MSRP',hue='Brand',data=df1)
# Out:
# <Axes: xlabel='Brand', ylabel='MSRP'>

# %%
# histogram for year and HP
plt.figure(figsize=(10,10))
sns.histplot(data=df1,x='Year',y='HP')
# Out:
# <Axes: xlabel='Year', ylabel='HP'>

# %%
# ploting the histogram for MSRP
plt.figure(figsize=(10,5))
sns.histplot(x='HP',data=df1,kde=True)
# Out:
# <Axes: xlabel='HP', ylabel='Count'>

# %%
# ploting the pie chart
plt.figure(figsize=(30,15))
df1['Brand'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# ploting the piechart for Transmission
plt.figure(figsize=(10,5))
df1['Transmission'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# violin plot for HP
plt.figure(figsize=(10,5))
sns.violinplot(x='HP',data=df1)
# Out:
# <Axes: xlabel='HP'>

# %%
# pairplot
sns.pairplot(df1)

# %%
# area plot
plt.figure(figsize=(10,5))
df1['HP'].plot(kind='area')
# Out:
# <Axes: >

# %% [markdown]
# 3-Dimension plots

# %%
# plotting 3D graphs
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import numpy as np

# %%
x=np.linspace(-5,5,100)
y=np.linspace(-5,5,100)
x,y=np.meshgrid(x,y)
z=np.sin(np.sqrt(x**2+y**2))

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(x,y,z,cmap='viridis')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
x=np.linspace(-5,5,100)
y=np.linspace(-5,5,100)
x,y=np.meshgrid(x,y)
z=(x**2+y**2)
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(x,y,z,cmap='plasma')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
x=np.linspace(-5,5,100)
y=np.linspace(-5,5,100)
x,y=np.meshgrid(x,y)
z=(x**3+y**3)
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(x,y,z,cmap='cool')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = x**2 - y**2
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='cividis')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z = X² - Y²')
plt.show()

# %%
x=df1['HP']
y=df1['MSRP']
x,y=np.meshgrid(x,y)
z=(x**2+y**2)
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(x,y,z,cmap='viridis')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
x=df1['HP']
y=df1['Cylinder']
x,y=np.meshgrid(x,y)
z=(x**2+y**2)
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(x,y,z,cmap='viridis')
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')
plt.show()

# %%
# Donut chart
plt.figure(figsize=(10,5))
labels = ['Python','Java','C++','C','Ruby']
sizes = [10,20,30,25,15]
fig,ax = plt.subplots()
ax.pie(sizes,labels=labels,startangle=90,wedgeprops={'width':0.4})
ax.axis('equal')
plt.title("Donut Chart")
plt.show()

# %%
# Donut chart
plt.figure(figsize=(10,5))
labels = ['Python','Java','C++','C','Ruby']
sizes = [10,20,30,25,15]
colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#ffb3e6']
fig,ax = plt.subplots()
ax.pie(sizes,labels=labels,colors=colors,autopct='%1.11f%%',startangle=90,wedgeprops={'width':0.4})
ax.axis('equal')
plt.title("Donut Chart")
plt.show()

# %%
df1['Transmission'].unique()
# Out:
# array(['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
#        'UNKNOWN'], dtype=object)

# %%
# size of each every unique value of the transmission
df1['Transmission'].value_counts()
# Out:
# Transmission
# AUTOMATIC           7772
# MANUAL              2498
# AUTOMATED_MANUAL     552
# DIRECT_DRIVE          53
# UNKNOWN               11
# Name: count, dtype: int64

# %%
len(df1)
# Out:
# 10886

# %%
# Donut chart for transmission and HP
plt.figure(figsize=(10,5))
labels = ['MANUAL', 'AUTOMATIC', 'AUTOMATED_MANUAL', 'DIRECT_DRIVE',
       'UNKNOWN']
sizes=[100*2498/10886,100*7772/10886,100*552/10886,100*53/10886,100*11/10886]
colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#ffb3e6']
fig,ax = plt.subplots()
ax.pie(sizes,labels=labels,colors=colors,autopct='%1.11f%%',startangle=90,wedgeprops={'width':0.4})
ax.axis('equal')
plt.title("Donut Chart")
plt.show()

# %%
labels = df1['Brand'].unique()
sizes = (df1['Brand'].value_counts())/len(df1)*100

# %%
fig,ax = plt.subplots()
ax.pie(sizes,labels=labels,startangle=90,wedgeprops={'width':0.6})
ax.axis('equal')
plt.title("Donut Chart")
plt.show()

# %%
labels = df1['Driven_Wheels'].unique()
sizes = (df1['Driven_Wheels'].value_counts())*100/len(df1)
fig,ax = plt.subplots()
ax.pie(sizes,labels=labels,startangle=90,wedgeprops={'width':0.6})
ax.axis('equal')
plt.title("Donut Chart")
plt.show()

# %%
# Polar plots
theata = np.linspace(0,2*np.pi,100)
r = np.abs(np.sin(5*theata))
plt.figure()
ax = plt.subplot(111,projection='polar')
ax.plot(theata,r)
plt.title("Polar Graph")
plt.show()

# %%
# Polar plots
theta = np.linspace(0,2*np.pi,6)
r = [1,2,3,4,3,2]
# Polar plots
theta = np.linspace(0,2*np.pi,6)
r = [1,2,3,4,3,2]
fig = plt.figure()
ax = fig.add_subplot(111,projection='polar')
bars=ax.bar(theta ,r, width=0.5,color='skyblue')
plt.title("Polar Graph")
plt.show()

# %%
# Polar plots
theata = np.linspace(0,2*np.pi,100)
r = np.abs(np.sin(theata))
plt.figure()
ax = plt.subplot(111,projection='polar')
ax.plot(theata,r)
plt.title("Polar Graph")
plt.show()
